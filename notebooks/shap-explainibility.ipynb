# %%
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sys
sys.path.append('..')
warnings.filterwarnings('ignore')

# %%
from src.shap_analysis import main

# %%
print("Running complete SHAP analysis...")
results = main()
# Out:
# Running complete SHAP analysis...
# TASK 3: MODEL EXPLAINABILITY WITH SHAP
# Loading model and data for SHAP analysis...
# Loaded: Random Forest model
#
# Converting data to numeric format for SHAP...
# Aligning columns between train and test...
# Training data: (5614, 12)
# Test data: (10000, 12)
# Training class distribution: {0: 9064, 1: 936}
#
# Identifying predictions for SHAP analysis...
# Found predictions for SHAP analysis:
#   True Positive: Index 11
#   False Positive: Index 233
#   False Negative: Index 2
#   True Negative: Index 0
# GLOBAL FEATURE IMPORTANCE - SHAP SUMMARY
# Using TreeExplainer for Random Forest...
# Top 10 features by mean |SHAP| value:
#         feature  mean_abs_shap
#  purchase_value       0.168847
#      source_SEO       0.168847
# browser_FireFox       0.011732
#     day_of_week       0.011732
#           sex_M       0.010985
#             age       0.010985
#     hour_of_day       0.009078
#      browser_IE       0.009078
# ...

# %%
print("ANALYSIS COMPLETE - SUMMARY")

if results:
    print("\nKey Results:")
    print(f"1. Top fraud driver: {results['shap_summary'].iloc[0]['feature']}")
    print(f"2. Number of features analyzed: {len(results['shap_summary'])}")
    print(
        f"3. Surprising findings identified: {len(results['surprising_findings'])}")
    print(
        f"4. Business recommendations generated: {len(results['recommendations'])}")

    print("\nFiles Created:")
    print(" models/shap_summary_plot.png")
    print(" models/builtin_feature_importance.png")
    print(" models/shap_builtin_comparison.png")
    print(" models/shap_force_true_positive.png")
    print(" models/shap_force_false_positive.png")
    print(" models/shap_force_false_negative.png")
    print(" models/shap_analysis_results.pkl")

print("\nTask 3 completed successfully!")
print("Project ready for final submission.")
